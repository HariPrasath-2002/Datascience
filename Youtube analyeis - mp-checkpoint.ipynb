# %%
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv(r'C:\Users\HP\OneDrive\Desktop\topSubscribed.csv')

# %%
df
# Out:
#      Rank             Youtube Channel  Subscribers      Video Views  \
# 0       1                    T-Series  234,000,000  212,900,271,553
# 1       2              YouTube Movies  161,000,000                0
# 2       3  Cocomelon - Nursery Rhymes  152,000,000  149,084,178,448
# 3       4                   SET India  150,000,000  137,828,094,104
# 4       5                     MrBeast  128,000,000   21,549,128,785
# ..    ...                         ...          ...              ...
# 995   996                     XO TEAM   11,500,000   11,471,384,709
# 996   997         Nirahua Music World   11,500,000    5,997,717,755
# 997   998                     YtCrash   11,400,000        3,825,084
# 998   999                   Painzeiro   11,400,000    2,143,444,281
# 999  1000                   Oum Walid   11,400,000    2,480,064,722
#
#     Video Count          Category  Started
# 0        18,515             Music     2006
# 1             0  Film & Animation     2015
# ...

# %%
df.describe()
# Out:
#               Rank      Started
# count  1000.000000  1000.000000
# mean    500.500000  2012.594000
# std     288.819436     4.110238
# min       1.000000  1970.000000
# 25%     250.750000  2010.000000
# 50%     500.500000  2013.000000
# 75%     750.250000  2015.000000
# max    1000.000000  2021.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Rank             1000 non-null   int64
#  1   Youtube Channel  1000 non-null   object
#  2   Subscribers      1000 non-null   object
#  3   Video Views      1000 non-null   object
#  4   Video Count      1000 non-null   object
#  5   Category         1000 non-null   object
#  6   Started          1000 non-null   int64
# dtypes: int64(2), object(5)
# memory usage: 54.8+ KB

# %%
df.shape
# Out:
# (1000, 7)

# %%
strings = ['Subscribers', 'Video Views', 'Video Count']
for s in strings:
    df[s] = pd.to_numeric(df[s].apply(lambda x: x.replace(',', '')))

# %%
df.iloc[df['Video Count'].argmax()]
# Out:
# Rank                           821
# Youtube Channel           GMA News
# Subscribers               12800000
# Video Views            11220255933
# Video Count                 342802
# Category           News & Politics
# Started                       2007
# Name: 820, dtype: object

# %%
df.iloc[df['Video Views'].argmax()]
# Out:
# Rank                          1
# Youtube Channel        T-Series
# Subscribers           234000000
# Video Views        212900271553
# Video Count               18515
# Category                  Music
# Started                    2006
# Name: 0, dtype: object

# %%
df.iloc[df['Subscribers'].argmax()]
# Out:
# Rank                          1
# Youtube Channel        T-Series
# Subscribers           234000000
# Video Views        212900271553
# Video Count               18515
# Category                  Music
# Started                    2006
# Name: 0, dtype: object

# %%
new_df = df[['Youtube Channel', 'Started']]
new_df
# Out:
#                 Youtube Channel  Started
# 0                      T-Series     2006
# 1                YouTube Movies     2015
# 2    Cocomelon - Nursery Rhymes     2006
# 3                     SET India     2006
# 4                       MrBeast     2012
# ..                          ...      ...
# 995                     XO TEAM     2021
# 996         Nirahua Music World     2014
# 997                     YtCrash     2015
# 998                   Painzeiro     2015
# 999                   Oum Walid     2015
#
# [1000 rows x 2 columns]

# %%
new_df = new_df.groupby("Started").count()

# %%
plt.figure(figsize=(12,9))
sns.set_theme(style="whitegrid")
ax = sns.barplot(x = new_df.index , y = 'Youtube Channel' , data= new_df)

# %%
df['Category'].value_counts()
# Out:
# Entertainment            238
# Music                    217
# People & Blogs           132
# Gaming                    94
# Comedy                    68
# Film & Animation          50
# Education                 45
# Shows                     44
# Howto & Style             43
# News & Politics           27
# Science & Technology      18
# Sports                    10
# Pets & Animals             6
# Trailers                   2
# Nonprofits & Activism      2
# Movies                     2
# Autos & Vehicles           1
# Travel & Events            1
# Name: Category, dtype: int64

# %%
df_pie =df.groupby('Category').count()

# %%
percent = (df_pie['Youtube Channel'])
sns.set()
plt.figure(figsize=(12 ,7))
sns.set_style("whitegrid")
patches , ax =  plt.pie(df_pie['Youtube Channel'] ,colors=sns.color_palette('Set2') )
labels = ['{0} - {1:1} '.format(i,j) for i,j in zip(df_pie.index, percent)]

sort_legend = True
if sort_legend:
    patches, labels , dummy=  zip(*sorted(zip(patches, labels, df_pie['Youtube Channel']),
                                          key=lambda x: x[2],
                                          reverse=True))
plt.legend(labels , loc='upper right', bbox_to_anchor=(-0.1, 1.))
plt.title("Category wise channel counts")
plt.show()

# %%
sns.residplot(data=df,x=df['Subscribers'],y=df['Video Views'])
plt.show()

# %%
plt.figure(figsize=(9,5))
plt.bar(df['Category'],df['Video Count'])
plt.xticks(rotation=90)
plt.xlabel("Category",fontsize=12,fontweight="bold")
plt.ylabel("No.of.videos",fontsize=12,fontweight="bold")

sns.set()
plt.show()

# %%
df2 = sum(df['Subscribers'])
df3= sum(df['Video Views'])
# Out:
# 21581400000 9994912409734

# %%
plt.figure(figsize=(30,40))
plt.bar(df2,df3)
plt.show()
